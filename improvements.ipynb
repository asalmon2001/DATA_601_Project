# %% [markdown]
# 23/10/05
#
# Alister Salmon

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
path = 'data/raw/improvement/'
df_2000 = pd.read_csv(path + 'improvement_2000.csv')
df_2005 = pd.read_csv(path + 'improvement_2005.csv')
df_2010 = pd.read_csv(path + 'improvement_2010.csv')
df_2015 = pd.read_csv(path + 'improvement_2015.csv')

# %%
# preview
display(df_2000)
# Out:
#           PermitNum AppliedDate                         PermitType  \
# 0      BP2000-00007  2000/01/03    Residential Improvement Project
# 1      BP2000-00008  2000/01/03    Residential Improvement Project
# 2      BP2000-00019  2000/01/03    Residential Improvement Project
# 3      BP2000-00011  2000/01/03    Residential Improvement Project
# 4      BP2000-00018  2000/01/03  Commercial / Multi Family Project
# ...             ...         ...                                ...
# 30039  BP2004-16982  2004/12/31    Residential Improvement Project
# 30040  BP2004-16977  2004/12/31  Commercial / Multi Family Project
# 30041  BP2004-16981  2004/12/31  Commercial / Multi Family Project
# 30042  BP2004-16978  2004/12/31    Residential Improvement Project
# 30043  BP2004-16979  2004/12/31  Commercial / Multi Family Project
#
#       PermitTypeMapped                      PermitClass PermitClassGroup  \
# 0             Building      1101 - Basement Development    Single Family
# ...

# %% [markdown]
# # Total demolition

# %%
# Get the number of demolitions in each half-decade
count_2000 = df_2000.shape[0]
count_2005 = df_2005.shape[0]
count_2010 = df_2010.shape[0]
count_2015 = df_2015.shape[0]

# %%
# Create our series
series = pd.Series([count_2000, count_2005, count_2010, count_2015])
series.rename({0:2000, 1:2005, 2:2010, 3:2015}, inplace=True)

# %%
series.plot(kind='bar', x='Half-Decade Start', title='Number of Improvement Permits Applied for')
# Out:
# <Axes: title={'center': 'Number of Improvement Permits Applied for'}>
