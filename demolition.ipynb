# %% [markdown]
# 23/10/05
#
# Alister Salmon

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
path = 'data/raw/demolition/'
df_2000 = pd.read_csv(path + 'demolition_2000.csv')
df_2005 = pd.read_csv(path + 'demolition_2005.csv')
df_2010 = pd.read_csv(path + 'demolition_2010.csv')
df_2015 = pd.read_csv(path + 'demolition_2015.csv')

# %%
# preview
display(df_2000)
# Out:
#          PermitNum AppliedDate  PermitType PermitTypeMapped  \
# 0     BP2000-00021  2000/01/04  Demolition       Demolition
# 1     BP2000-00062  2000/01/05  Demolition       Demolition
# 2     BP2000-00063  2000/01/05  Demolition       Demolition
# 3     BP2000-00157  2000/01/07  Demolition       Demolition
# 4     BP2000-00206  2000/01/11  Demolition       Demolition
# ...            ...         ...         ...              ...
# 2117  BP2004-16832  2004/12/23  Demolition       Demolition
# 2118  BP2004-16886  2004/12/24  Demolition       Demolition
# 2119  BP2004-16946  2004/12/29  Demolition       Demolition
# 2120  BP2004-16945  2004/12/29  Demolition       Demolition
# 2121  BP2004-16975  2004/12/30  Demolition       Demolition
#
#                           PermitClass PermitClassGroup PermitClassMapped  \
# 0                        1106 - House    Single Family       Residential
# 1                        1106 - House    Single Family       Residential
# ...

# %% [markdown]
# # Total demolition

# %%
# Get the number of demolitions in each half-decade
count_2000 = df_2000.shape[0]
count_2005 = df_2005.shape[0]
count_2010 = df_2010.shape[0]
count_2015 = df_2015.shape[0]

# %%
# Create our series
series = pd.Series([count_2000, count_2005, count_2010, count_2015])
series.rename({0:2000, 1:2005, 2:2010, 3:2015}, inplace=True)

# %%
series.plot(kind='bar', x='Half-Decade Start', title='Number of Demolition Permits Applied for')
# Out:
# <Axes: title={'center': 'Number of Demolition Permits Applied for'}>
