# %% [markdown]
# 23/10/05
#
# Alister Salmon

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
path = 'data/raw/new/non_residential/'
df_2000 = pd.read_csv(path + 'new_non_residential_2000.csv')
df_2005 = pd.read_csv(path + 'new_non_residential_2005.csv')
df_2010 = pd.read_csv(path + 'new_non_residential_2010.csv')
df_2015 = pd.read_csv(path + 'new_non_residential_2015.csv')

# %%
# preview
display(df_2000)
# Out:
#          PermitNum AppliedDate                         PermitType  \
# 0     BP2000-00113  2000/01/06  Commercial / Multi Family Project
# 1     BP2000-00148  2000/01/07  Commercial / Multi Family Project
# 2     BP2000-00116  2000/01/07  Commercial / Multi Family Project
# 3     BP2000-00224  2000/01/11  Commercial / Multi Family Project
# 4     BP2000-00247  2000/01/12  Commercial / Multi Family Project
# ...            ...         ...                                ...
# 1480  BP2004-16258  2004/12/08  Commercial / Multi Family Project
# 1481  BP2004-16661  2004/12/17  Commercial / Multi Family Project
# 1482  BP2004-16884  2004/12/24  Commercial / Multi Family Project
# 1483  BP2004-16878  2004/12/24  Commercial / Multi Family Project
# 1484  BP2004-16922  2004/12/29  Commercial / Multi Family Project
#
#      PermitTypeMapped                        PermitClass PermitClassGroup  \
# 0            Building            3204 - Warehouse/Office       Commercial
# 1            Building                     3303 - Gas Bar       Commercial
# 2            Building  2379 - Indust/Communication Misc.       Industrial
# 3            Building             5199 - Education Misc.    Institutional
# 4            Building                      3402 - Office       Commercial
# ...               ...                                ...              ...
# 1480         Building            3204 - Warehouse/Office       Commercial
# 1481         Building           2507 - Veterinary Clinic       Industrial
# 1482         Building         3399 - Motor-Vehicle Misc.       Commercial
# 1483         Building              5109 - School, Public    Institutional
# 1484         Building       5115 - University Of Calgary    Institutional
#
#      PermitClassMapped WorkClass                        Description
# 0      Non-Residential       New            new industrial building
# 1      Non-Residential       New                 New Gas Bar Canopy
# 2      Non-Residential       New  New communication tower - shelter
# 3      Non-Residential       New           New Rec, Ed, and Library
# 4      Non-Residential       New                       New Building
# ...                ...       ...                                ...
# 1480   Non-Residential       New     New Commercial ( Building 'A')
# 1481   Non-Residential       New            New Commercial Building
# 1482   Non-Residential       New                       NEW BUILDING
# 1483   Non-Residential       New           New School & 6 portables
# 1484   Non-Residential       New                      New Vestibule
#
# [1485 rows x 9 columns]

# %% [markdown]
# # Total demolition

# %%
# Get the number of demolitions in each half-decade
count_2000 = df_2000.shape[0]
count_2005 = df_2005.shape[0]
count_2010 = df_2010.shape[0]
count_2015 = df_2015.shape[0]

# %%
# Create our series
series = pd.Series([count_2000, count_2005, count_2010, count_2015])
series.rename({0:2000, 1:2005, 2:2010, 3:2015}, inplace=True)

# %%
series.plot(kind='bar', x='Half-Decade Start', title='Number of New Non-Residential Permits Applied for')
# Out:
# <Axes: title={'center': 'Number of New Non-Residential Permits Applied for'}>
